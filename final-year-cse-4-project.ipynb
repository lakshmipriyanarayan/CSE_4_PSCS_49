# %%
# !pip install -U scikit-learn imbalanced-learn

# %%
# =============================================
# STEP 1: IMPORT LIBRARIES
# =============================================
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, accuracy_score
from sklearn.preprocessing import label_binarize
from itertools import cycle
import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# =============================================
# STEP 2: IMPORT DATA & EDA
# =============================================
print("--- [Step 2] Loading Data and Performing EDA ---")

# Import Data (as provided in original code)
data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv')
y = data['label']
x = data.drop(columns = ['label'])

# Load metadata for Exploratory Data Analysis (EDA)
tabular_data = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')

# --- EDA Plot 1: Frequency Distribution of Classes ---
plt.figure(figsize=(10, 6))
sns.countplot(x = 'dx', data = tabular_data)
plt.xlabel('Disease', size=12)
plt.ylabel('Frequency', size=12)
plt.title('Frequency Distribution of Classes', size=16)
plt.show()

# Define class names for plotting
classes = {
    4: ('nv', ' melanocytic nevi'), 
    6: ('mel', 'melanoma'), 
    2 :('bkl', 'benign keratosis-like lesions'), 
    1:('bcc' , ' basal cell carcinoma'), 
    5: ('vasc', ' pyogenic granulomas and hemorrhage'), 
    0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  
    3: ('df', 'dermatofibroma')
}
class_names_list = [classes[i][1].strip() for i in sorted(classes.keys())]

# --- EDA Plot 2: Distribution of Disease over Gender ---
plt.figure(figsize = (8, 8))
plt.pie(tabular_data['sex'].value_counts(), labels = tabular_data['sex'].value_counts().index, autopct="%.1f%%")
plt.title('Gender of Patient', size=16)
plt.show()

# --- EDA Plot 3: Histogram of Age of Patients ---
plt.figure(figsize=(10, 6))
sns.histplot(tabular_data['age'])
plt.title('Histogram of Age of Patients', size=16)
plt.show()

# --- EDA Plot 4: Location of disease over Gender ---
value = tabular_data[['localization', 'sex']].value_counts().to_frame()
value.reset_index(level=[1,0 ], inplace=True)
temp = value.rename(columns = {'localization':'location', 0: 'count'})
plt.figure(figsize = (12, 8))
sns.barplot(x = 'location',  y='count', hue = 'sex', data = temp)
plt.title('Location of disease over Gender', size = 16)
plt.xlabel('Disease', size=12)
plt.ylabel('Frequency/Count', size=12)
plt.xticks(rotation = 90)
plt.show()

# =============================================
# STEP 3: DATA PREPROCESSING
# =============================================
print("\n--- [Step 3] Preprocessing Data ---")

# Oversampling to overcome class imbalance
print(f"Original data shape: {x.shape}")
oversample = RandomOverSampler()
x, y  = oversample.fit_resample(x, y)
print(f"Oversampled data shape: {x.shape}")

# Reshape to 28x28x3
x = np.array(x).reshape(-1, 28, 28, 3)
print(f"Reshaped x shape: {x.shape}")

# Standardization (Z-score normalization)
x = (x - np.mean(x)) / np.std(x)
print("Data standardized.")

# Splitting Data
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=1)
print(f"Train/Test split complete. Training size: {X_train.shape[0]}, Test size: {X_test.shape[0]}")

# =============================================
# STEP 4: MODEL TRAINING (PERSONALIZED)
# =============================================
print("\n--- [Step 4] Building and Training Personalized CNN ---")

# --- Define the Personalized Model Architecture ---
model = Sequential()
model.add(Conv2D(16, kernel_size=(3, 3), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(BatchNormalization()) # New: Stabilizes training
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization()) # New
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25)) # New: Prevents overfitting

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization()) # New
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization()) # New
model.add(MaxPool2D(pool_size=(2, 2), padding='same'))
model.add(Dropout(0.25)) # New

model.add(Flatten())
model.add(Dense(128, activation='relu')) # Modified: Increased capacity
model.add(BatchNormalization()) # New
model.add(Dropout(0.5)) # New
model.add(Dense(64, activation='relu')) # Modified: Increased capacity
model.add(Dense(7, activation='softmax')) # 7 classes

model.summary()

# --- Define Save Path and Callbacks ---
SAVE_DIR = "/kaggle/working/LPmodcse4/"
os.makedirs(SAVE_DIR, exist_ok=True)
model_path = os.path.join(SAVE_DIR, "best_model.h5")

# Changed ModelCheckpoint to monitor 'val_accuracy'
callbacks = [
    ModelCheckpoint(filepath=model_path, monitor='val_accuracy', mode='max', verbose=1, save_best_only=True),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.1, min_lr=1e-6)
]

# --- Compile and Train ---
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size=128,
                    epochs=50, # Increased epochs, but EarlyStopping will find the best one
                    callbacks=callbacks)

# =============================================
# STEP 5: MODEL EVALUATION (ENHANCED)
# =============================================
print("\n--- [Step 5] Loading Best Model and Evaluating ---")

# Load the best model saved by ModelCheckpoint
model.load_weights(model_path)

# --- Metric 1: Plot Accuracy and Loss ---
print("\n--- Training History ---")
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# --- Metric 2: Final Test Accuracy ---
loss, acc = model.evaluate(X_test, Y_test, verbose=1)
print(f"\n✅ Final Test Accuracy: {acc * 100:.2f}%")

# --- Metric 3: Classification Report (Precision, Recall, F1-Score) ---
print("\n--- Classification Report ---")
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = Y_test
print(classification_report(y_true, y_pred, target_names=class_names_list))

# --- Metric 4: Confusion Matrix ---
print("\n--- Confusion Matrix ---")
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names_list, yticklabels=class_names_list)
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# --- Metric 5: Multi-Class ROC/AUC Curves ---
print("\n--- ROC/AUC Curves ---")
y_true_bin = label_binarize(y_true, classes=list(range(7)))
n_classes = 7

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute macro-average ROC curve and ROC area
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(figsize=(12, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green', 'red', 'purple', 'brown'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve of {class_names_list[i]} (area = {roc_auc[i]:.2f})')

plt.plot(fpr["macro"], tpr["macro"],
         label=f'Macro-average ROC (area = {roc_auc["macro"]:.2f})',
         color='navy', linestyle=':', linewidth=4)

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()
# Out:
# --- [Step 2] Loading Data and Performing EDA ---
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# --- [Step 3] Preprocessing Data ---
# Original data shape: (10015, 2352)
# Oversampled data shape: (46935, 2352)
# Reshaped x shape: (46935, 28, 28, 3)
# Data standardized.
# Train/Test split complete. Training size: 37548, Test size: 9387
#
# --- [Step 4] Building and Training Personalized CNN ---
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1762094373.859552     131 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1762094373.860210     131 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 26, 26, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 13, 13, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 13, 13, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 11, 11, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 337,671 (1.29 MB)
#  Trainable params: 337,127 (1.29 MB)
#  Non-trainable params: 544 (2.12 KB)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762094381.124650     185 service.cc:148] XLA service 0x7b4d64002ac0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762094381.125223     185 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1762094381.125245     185 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1762094381.693738     185 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  18/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2483 - loss: 2.3739
# I0000 00:00:1762094386.985358     185 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4496 - loss: 1.5433
# Epoch 1: val_accuracy improved from -inf to 0.46644, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - accuracy: 0.4500 - loss: 1.5419 - val_accuracy: 0.4664 - val_loss: 1.3597 - learning_rate: 0.0010
# Epoch 2/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6953 - loss: 0.8204
# Epoch 2: val_accuracy improved from 0.46644 to 0.80413, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6955 - loss: 0.8199 - val_accuracy: 0.8041 - val_loss: 0.5349 - learning_rate: 0.0010
# Epoch 3/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7640 - loss: 0.6338
# Epoch 3: val_accuracy improved from 0.80413 to 0.81678, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7643 - loss: 0.6331 - val_accuracy: 0.8168 - val_loss: 0.4712 - learning_rate: 0.0010
# Epoch 4/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8052 - loss: 0.5200
# Epoch 4: val_accuracy improved from 0.81678 to 0.86644, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8053 - loss: 0.5198 - val_accuracy: 0.8664 - val_loss: 0.3451 - learning_rate: 0.0010
# Epoch 5/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8340 - loss: 0.4409
# Epoch 5: val_accuracy improved from 0.86644 to 0.89521, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8342 - loss: 0.4405 - val_accuracy: 0.8952 - val_loss: 0.2921 - learning_rate: 0.0010
# Epoch 6/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8532 - loss: 0.3847
# Epoch 6: val_accuracy improved from 0.89521 to 0.90839, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8533 - loss: 0.3845 - val_accuracy: 0.9084 - val_loss: 0.2458 - learning_rate: 0.0010
# Epoch 7/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8707 - loss: 0.3425
# Epoch 7: val_accuracy improved from 0.90839 to 0.91944, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8707 - loss: 0.3425 - val_accuracy: 0.9194 - val_loss: 0.2211 - learning_rate: 0.0010
# Epoch 8/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8817 - loss: 0.3174
# Epoch 8: val_accuracy improved from 0.91944 to 0.92650, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8816 - loss: 0.3174 - val_accuracy: 0.9265 - val_loss: 0.2024 - learning_rate: 0.0010
# Epoch 9/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8917 - loss: 0.2827
# Epoch 9: val_accuracy improved from 0.92650 to 0.93142, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8918 - loss: 0.2826 - val_accuracy: 0.9314 - val_loss: 0.1960 - learning_rate: 0.0010
# Epoch 10/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9035 - loss: 0.2597
# Epoch 10: val_accuracy improved from 0.93142 to 0.93529, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9035 - loss: 0.2597 - val_accuracy: 0.9353 - val_loss: 0.1811 - learning_rate: 0.0010
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9058 - loss: 0.2490
# Epoch 11: val_accuracy improved from 0.93529 to 0.94234, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9058 - loss: 0.2490 - val_accuracy: 0.9423 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 12/50
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9108 - loss: 0.2274
# Epoch 12: val_accuracy improved from 0.94234 to 0.94714, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9109 - loss: 0.2273 - val_accuracy: 0.9471 - val_loss: 0.1446 - learning_rate: 0.0010
# Epoch 13/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9220 - loss: 0.2033
# Epoch 13: val_accuracy improved from 0.94714 to 0.94993, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9220 - loss: 0.2033 - val_accuracy: 0.9499 - val_loss: 0.1455 - learning_rate: 0.0010
# Epoch 14/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9243 - loss: 0.2065
# Epoch 14: val_accuracy improved from 0.94993 to 0.95220, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9243 - loss: 0.2064 - val_accuracy: 0.9522 - val_loss: 0.1401 - learning_rate: 0.0010
# Epoch 15/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9257 - loss: 0.1937
# Epoch 15: val_accuracy did not improve from 0.95220
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9258 - loss: 0.1937 - val_accuracy: 0.9510 - val_loss: 0.1326 - learning_rate: 0.0010
# Epoch 16/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9342 - loss: 0.1776
# Epoch 16: val_accuracy improved from 0.95220 to 0.95686, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9342 - loss: 0.1776 - val_accuracy: 0.9569 - val_loss: 0.1289 - learning_rate: 0.0010
# Epoch 17/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9326 - loss: 0.1796
# Epoch 17: val_accuracy did not improve from 0.95686
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9326 - loss: 0.1795 - val_accuracy: 0.9541 - val_loss: 0.1303 - learning_rate: 0.0010
# Epoch 18/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9401 - loss: 0.1568
# Epoch 18: val_accuracy improved from 0.95686 to 0.95846, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9401 - loss: 0.1568 - val_accuracy: 0.9585 - val_loss: 0.1212 - learning_rate: 0.0010
# Epoch 19/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9423 - loss: 0.1575
# Epoch 19: val_accuracy improved from 0.95846 to 0.96378, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9424 - loss: 0.1575 - val_accuracy: 0.9638 - val_loss: 0.1094 - learning_rate: 0.0010
# Epoch 20/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9467 - loss: 0.1469
# Epoch 20: val_accuracy improved from 0.96378 to 0.96405, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9467 - loss: 0.1469 - val_accuracy: 0.9640 - val_loss: 0.1030 - learning_rate: 0.0010
# Epoch 21/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9480 - loss: 0.1364
# Epoch 21: val_accuracy improved from 0.96405 to 0.96551, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9480 - loss: 0.1363 - val_accuracy: 0.9655 - val_loss: 0.1017 - learning_rate: 0.0010
# Epoch 22/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9493 - loss: 0.1378
# Epoch 22: val_accuracy did not improve from 0.96551
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9493 - loss: 0.1377 - val_accuracy: 0.9607 - val_loss: 0.1136 - learning_rate: 0.0010
# Epoch 23/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9484 - loss: 0.1386
# Epoch 23: val_accuracy did not improve from 0.96551
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9484 - loss: 0.1385 - val_accuracy: 0.9627 - val_loss: 0.1070 - learning_rate: 0.0010
# Epoch 24/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9505 - loss: 0.1352
# Epoch 24: val_accuracy did not improve from 0.96551
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9505 - loss: 0.1352 - val_accuracy: 0.9638 - val_loss: 0.1011 - learning_rate: 0.0010
# Epoch 25/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9548 - loss: 0.1233
# Epoch 25: val_accuracy did not improve from 0.96551
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9548 - loss: 0.1233 - val_accuracy: 0.9643 - val_loss: 0.1128 - learning_rate: 0.0010
# Epoch 26/50
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9569 - loss: 0.1203
# Epoch 26: val_accuracy did not improve from 0.96551
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9569 - loss: 0.1203 - val_accuracy: 0.9623 - val_loss: 0.1149 - learning_rate: 0.0010
# Epoch 27/50
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9564 - loss: 0.1196
# Epoch 27: val_accuracy did not improve from 0.96551
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9564 - loss: 0.1197 - val_accuracy: 0.9595 - val_loss: 0.1225 - learning_rate: 0.0010
# Epoch 28/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9582 - loss: 0.1138
# Epoch 28: val_accuracy improved from 0.96551 to 0.96884, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9582 - loss: 0.1138 - val_accuracy: 0.9688 - val_loss: 0.0944 - learning_rate: 0.0010
# Epoch 29/50
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9652 - loss: 0.1003
# Epoch 29: val_accuracy did not improve from 0.96884
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9651 - loss: 0.1004 - val_accuracy: 0.9652 - val_loss: 0.1022 - learning_rate: 0.0010
# Epoch 30/50
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9614 - loss: 0.1063
# Epoch 30: val_accuracy improved from 0.96884 to 0.96964, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9614 - loss: 0.1063 - val_accuracy: 0.9696 - val_loss: 0.0858 - learning_rate: 0.0010
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9609 - loss: 0.1056
# Epoch 31: val_accuracy improved from 0.96964 to 0.97071, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9609 - loss: 0.1056 - val_accuracy: 0.9707 - val_loss: 0.0908 - learning_rate: 0.0010
# Epoch 32/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9648 - loss: 0.0995
# Epoch 32: val_accuracy improved from 0.97071 to 0.97403, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9648 - loss: 0.0995 - val_accuracy: 0.9740 - val_loss: 0.0852 - learning_rate: 0.0010
# Epoch 33/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9663 - loss: 0.0926
# Epoch 33: val_accuracy did not improve from 0.97403
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9662 - loss: 0.0927 - val_accuracy: 0.9731 - val_loss: 0.0833 - learning_rate: 0.0010
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9636 - loss: 0.0954
# Epoch 34: val_accuracy did not improve from 0.97403
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9636 - loss: 0.0954 - val_accuracy: 0.9723 - val_loss: 0.0885 - learning_rate: 0.0010
# Epoch 35/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9642 - loss: 0.0961
# Epoch 35: val_accuracy did not improve from 0.97403
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9642 - loss: 0.0961 - val_accuracy: 0.9700 - val_loss: 0.0948 - learning_rate: 0.0010
# Epoch 36/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9671 - loss: 0.0938
# Epoch 36: val_accuracy did not improve from 0.97403
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9671 - loss: 0.0937 - val_accuracy: 0.9735 - val_loss: 0.0855 - learning_rate: 0.0010
# Epoch 37/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9662 - loss: 0.0908
# Epoch 37: val_accuracy did not improve from 0.97403
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9663 - loss: 0.0906 - val_accuracy: 0.9707 - val_loss: 0.0903 - learning_rate: 0.0010
# Epoch 38/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9682 - loss: 0.0899
# Epoch 38: val_accuracy did not improve from 0.97403
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9683 - loss: 0.0899 - val_accuracy: 0.9671 - val_loss: 0.1035 - learning_rate: 0.0010
# Epoch 39/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9731 - loss: 0.0762
# Epoch 39: val_accuracy improved from 0.97403 to 0.97683, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9732 - loss: 0.0761 - val_accuracy: 0.9768 - val_loss: 0.0723 - learning_rate: 1.0000e-04
# Epoch 40/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9787 - loss: 0.0599
# Epoch 40: val_accuracy improved from 0.97683 to 0.97696, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9787 - loss: 0.0599 - val_accuracy: 0.9770 - val_loss: 0.0719 - learning_rate: 1.0000e-04
# Epoch 41/50
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9794 - loss: 0.0549
# Epoch 41: val_accuracy did not improve from 0.97696
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9794 - loss: 0.0549 - val_accuracy: 0.9767 - val_loss: 0.0707 - learning_rate: 1.0000e-04
# Epoch 42/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9806 - loss: 0.0545
# Epoch 42: val_accuracy improved from 0.97696 to 0.97883, saving model to /kaggle/working/LPmodcse4/best_model.h5
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9806 - loss: 0.0545 - val_accuracy: 0.9788 - val_loss: 0.0680 - learning_rate: 1.0000e-04
# Epoch 43/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9811 - loss: 0.0525
# Epoch 43: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9811 - loss: 0.0525 - val_accuracy: 0.9779 - val_loss: 0.0716 - learning_rate: 1.0000e-04
# Epoch 44/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0511
# Epoch 44: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9812 - loss: 0.0511 - val_accuracy: 0.9786 - val_loss: 0.0699 - learning_rate: 1.0000e-04
# Epoch 45/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.0517
# Epoch 45: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9813 - loss: 0.0516 - val_accuracy: 0.9776 - val_loss: 0.0721 - learning_rate: 1.0000e-04
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9814 - loss: 0.0497
# Epoch 46: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9814 - loss: 0.0497 - val_accuracy: 0.9771 - val_loss: 0.0746 - learning_rate: 1.0000e-04
# Epoch 47/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9851 - loss: 0.0446
# Epoch 47: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9851 - loss: 0.0447 - val_accuracy: 0.9786 - val_loss: 0.0712 - learning_rate: 1.0000e-04
# Epoch 48/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9858 - loss: 0.0434
# Epoch 48: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9858 - loss: 0.0433 - val_accuracy: 0.9788 - val_loss: 0.0717 - learning_rate: 1.0000e-05
# Epoch 49/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9845 - loss: 0.0416
# Epoch 49: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9845 - loss: 0.0417 - val_accuracy: 0.9786 - val_loss: 0.0728 - learning_rate: 1.0000e-05
# Epoch 50/50
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.0417
# Epoch 50: val_accuracy did not improve from 0.97883
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9850 - loss: 0.0417 - val_accuracy: 0.9786 - val_loss: 0.0725 - learning_rate: 1.0000e-05
#
# --- [Step 5] Loading Best Model and Evaluating ---
#
# --- Training History ---
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9766 - loss: 0.0787
#
# ✅ Final Test Accuracy: 97.79%
#
# --- Classification Report ---
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
#                                                   precision    recall  f1-score   support
#
# Actinic keratoses and intraepithelial carcinomae       1.00      1.00      1.00      1359
#                             basal cell carcinoma       0.99      1.00      0.99      1318
#                    benign keratosis-like lesions       0.95      1.00      0.97      1262
#                                   dermatofibroma       1.00      1.00      1.00      1351
#                                 melanocytic nevi       0.99      0.86      0.92      1374
#               pyogenic granulomas and hemorrhage       0.99      1.00      1.00      1358
#                                         melanoma       0.93      0.99      0.96      1365
#
#                                         accuracy                           0.98      9387
#                                        macro avg       0.98      0.98      0.98      9387
#                                     weighted avg       0.98      0.98      0.98      9387
#
#
# --- Confusion Matrix ---
# --- ROC/AUC Curves ---
